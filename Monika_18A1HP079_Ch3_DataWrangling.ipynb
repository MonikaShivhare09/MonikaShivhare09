# %% [markdown]
# ## Data Wrangling

# %%
# import required libraries
import random
import datetime 
import numpy as np
import pandas as pd
from random import randrange
from sklearn import preprocessing

pd.options.mode.chained_assignment = None

# %%
def _random_date(start,date_count):
    """This function generates a random date based on params
    Args:
        start (date object): the base date
        date_count (int): number of dates to be generated
    Returns:
        list of random dates

    """
    current = start
    while date_count > 0:
        curr = current + datetime.timedelta(days=randrange(42))
        yield curr
        date_count-=1


def generate_sample_data(row_count=100):
    """This function generates a random transaction dataset
    Args:
        row_count (int): number of rows for the dataframe
    Returns:
        a pandas dataframe

    """
    
    # sentinels
    startDate = datetime.datetime(2016, 1, 1,13)
    serial_number_sentinel = 1000
    user_id_sentinel = 5001
    product_id_sentinel = 101
    price_sentinel = 2000
    
    
    # base list of attributes
    data_dict = {
    'Serial No': np.arange(row_count)+serial_number_sentinel,
    'Date': np.random.permutation(pd.to_datetime([x.strftime("%d-%m-%Y") 
                                                    for x in _random_date(startDate,
                                                                          row_count)]).date
                                  ),
    'User ID': np.random.permutation(np.random.randint(0,
                                                       row_count,
                                                       size=int(row_count/10)) + user_id_sentinel).tolist()*10,
    'Product ID': np.random.permutation(np.random.randint(0,
                                                          row_count,
                                                          size=int(row_count/10))+ product_id_sentinel).tolist()*10 ,
    'Quantity Purchased': np.random.permutation(np.random.randint(1,
                                                                  42,
                                                                  size=row_count)),
    'Price': np.round(np.abs(np.random.randn(row_count)+1)*price_sentinel,
                      decimals=2),
    'User Type':np.random.permutation([chr(random.randrange(97, 97 + 3 + 1)) 
                                            for i in range(row_count)])
    }
    
    # introduce missing values
    for index in range(int(np.sqrt(row_count))): 
        data_dict['Price'][np.argmax(data_dict['Price'] == random.choice(data_dict['Price']))] = np.nan
        data_dict['User Type'][np.argmax(data_dict['User Type'] == random.choice(data_dict['User Type']))] = np.nan
        data_dict['Date'][np.argmax(data_dict['Date'] == random.choice(data_dict['Date']))] = np.nan
        data_dict['Product ID'][np.argmax(data_dict['Product ID'] == random.choice(data_dict['Product ID']))] = 0
        data_dict['Serial No'][np.argmax(data_dict['Serial No'] == random.choice(data_dict['Serial No']))] = -1
        data_dict['User ID'][np.argmax(data_dict['User ID'] == random.choice(data_dict['User ID']))] = -101
        
    
    # create data frame
    df = pd.DataFrame(data_dict)
    
    return df
    

def describe_dataframe(df=pd.DataFrame()):
    """This function generates descriptive stats of a dataframe
    Args:
        df (dataframe): the dataframe to be analyzed
    Returns:
        None

    """
    print("\n\n")
    print("*"*30)
    print("About the Data")
    print("*"*30)
    
    print("Number of rows::",df.shape[0])
    print("Number of columns::",df.shape[1])
    print("\n")
    
    print("Column Names::",df.columns.values.tolist())
    print("\n")
    
    print("Column Data Types::\n",df.dtypes)
    print("\n")
    
    print("Columns with Missing Values::",df.columns[df.isnull().any()].tolist())
    print("\n")
    
    print("Number of rows with Missing Values::",len(pd.isnull(df).any(1).nonzero()[0].tolist()))
    print("\n")
    
    print("Sample Indices with missing data::",pd.isnull(df).any(1).nonzero()[0].tolist()[0:5])
    print("\n")
    
    print("General Stats::")
    print(df.info())
    print("\n")
    
    print("Summary Stats::")
    print(df.describe())
    print("\n")
    
    print("Dataframe Sample Rows::")
    display(df.head(5))
    
def cleanup_column_names(df,rename_dict={},do_inplace=True):
    """This function renames columns of a pandas dataframe
       It converts column names to snake case if rename_dict is not passed. 
    Args:
        rename_dict (dict): keys represent old column names and values point to 
                            newer ones
        do_inplace (bool): flag to update existing dataframe or return a new one
    Returns:
        pandas dataframe if do_inplace is set to False, None otherwise

    """
    if not rename_dict:
        return df.rename(columns={col: col.lower().replace(' ','_') 
                    for col in df.columns.values.tolist()}, 
                  inplace=do_inplace)
    else:
        return df.rename(columns=rename_dict,inplace=do_inplace)

def expand_user_type(u_type):
    """This function maps user types to user classes
    Args:
        u_type (str): user type value
    Returns:
        (str) user_class value

    """
    if u_type in ['a','b']:
        return 'new'
    elif u_type == 'c':
        return 'existing'
    elif u_type == 'd':
        return 'loyal_existing'
    else:
        return 'error'

# %%
df = generate_sample_data(row_count=1000)

# %%
describe_dataframe(df)
# Out:
# ******************************
# About the Data
# ******************************
# Number of rows:: 1000
# Number of columns:: 7
#
#
# Column Names:: ['Serial No', 'Date', 'User ID', 'Product ID', 'Quantity Purchased', 'Price', 'User Type']
#
#
# Column Data Types::
#  Serial No               int32
# Date                   object
# User ID                 int64
# Product ID              int64
# Quantity Purchased      int32
# Price                 float64
# User Type              object
# dtype: object
#
#
# Columns with Missing Values:: ['Date', 'Price']
#
#
# Number of rows with Missing Values:: 62
#
#
# Sample Indices with missing data:: [0, 2, 3, 5, 8]
#
#
# General Stats::
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# Serial No             1000 non-null int32
# Date                  969 non-null object
# User ID               1000 non-null int64
# Product ID            1000 non-null int64
# Quantity Purchased    1000 non-null int32
# Price                 969 non-null float64
# User Type             1000 non-null object
# dtypes: float64(1), int32(2), int64(2), object(2)
# memory usage: 47.0+ KB
# None
#
#
# Summary Stats::
#          Serial No      User ID   Product ID  Quantity Purchased        Price
# count  1000.000000  1000.000000  1000.000000          1000.00000   969.000000
# mean   1452.168000  5475.978000   564.854000            20.98700  2281.300206
# std     385.476219   344.705621   265.818306            12.10063  1600.517012
# min      -1.000000  -101.000000     0.000000             1.00000     3.070000
# 25%    1224.750000  5224.000000   341.500000            10.00000   940.330000
# 50%    1482.500000  5468.000000   584.500000            21.00000  2032.900000
# 75%    1741.250000  5754.000000   766.250000            31.00000  3355.910000
# max    1999.000000  5994.000000  1100.000000            41.00000  9681.510000
#
#
# Dataframe Sample Rows::
# C:\Users\asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:98: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
# C:\Users\asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:101: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#    Serial No        Date  User ID  Product ID  Quantity Purchased    Price  \
# 0       1000         NaN     -101           0                   3  1210.88
# 1       1001  2016-01-19     5763         898                   2  1441.29
# 2       1002         NaN     5358         896                  18  4778.68
# 3       1003  2016-08-02     5691         442                   6      NaN
# 4       1004  2016-05-02     5492         227                  17  3448.13
#
#   User Type
# 0         n
# 1         n
# 2         n
# 3         n
# 4         n

# %% [markdown]
# ### rename columns

# %%
print("Dataframe columns:\n{}".format(df.columns.tolist()))
# Out:
# Dataframe columns:
# ['Serial No', 'Date', 'User ID', 'Product ID', 'Quantity Purchased', 'Price', 'User Type']

# %%
#sorting in ascending order the row attributes
display(df.sort_values(['serial_no', 'price'], 
                         ascending=[True, False]).head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-433217d42f50> in <module>
#       1 #sorting in ascending order the row attributes
#       2 display(df.sort_values(['serial_no', 'price'],
# ----> 3                          ascending=[True, False]).head())
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4709
#    4710             keys = [self._get_label_or_level_values(x, axis=axis)
# -> 4711                     for x in by]
#    4712             indexer = lexsort_indexer(keys, orders=ascending,
#    4713                                       na_position=na_position)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in <listcomp>(.0)
#    4709
#    4710             keys = [self._get_label_or_level_values(x, axis=axis)
# -> 4711                     for x in by]
#    4712             indexer = lexsort_indexer(keys, orders=ascending,
#    4713                                       na_position=na_position)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: 'serial_no'

# %%
cleanup_column_names(df)

# %%
print("Dataframe columns:\n{}".format(df.columns.tolist()))
# Out:
# Dataframe columns:
# ['serial_no', 'date', 'user_id', 'product_id', 'quantity_purchased', 'price', 'user_type']

# %%
#ascending order sorting for rows
display(df.sort_values(['serial_no', 'price'], 
                         ascending=[True, False]).head())
# Out:
#      serial_no        date  user_id  product_id  quantity_purchased    price  \
# 367         -1  2016-01-13     5672         594                  40  6010.70
# 964         -1  2016-01-17     5508         334                  12  4112.63
# 176         -1  2016-01-17     5156         273                  33  4100.23
# 615         -1  2016-10-02     5349         286                  40  3630.10
# 317         -1  2016-01-23     5729         610                  40  3355.91
#
#     user_type
# 367         b
# 964         c
# 176         b
# 615         b
# 317         a

# %%
#rearranging columns in data frame
display(df[['serial_no','date','user_id','user_type',
              'product_id','quantity_purchased','price']].head())
# Out:
#    serial_no        date  user_id user_type  product_id  quantity_purchased  \
# 0       1000         NaN     -101         n           0                   3
# 1       1001  2016-01-19     5763         n         898                   2
# 2       1002         NaN     5358         n         896                  18
# 3       1003  2016-08-02     5691         n         442                   6
# 4       1004  2016-05-02     5492         n         227                  17
#
#      price
# 0  1210.88
# 1  1441.29
# 2  4778.68
# 3      NaN
# 4  3448.13

# %% [markdown]
# ## Filtering Columns

# %%
# print 10 values from column at index 3
print(df.iloc[:,3].values[0:10])
# Out:
# [  0 898 896 442 227 196 295 421 583 981]

# %%
# print 10 values of quantity  by using column name
print(df.quantity_purchased.values[0:10])
# Out:
# [ 3  2 18  6 17  1 19 31 35 19]

# %%
# print 10 values of columns with data type float using data type
print(df.select_dtypes(include=['float64']).values[:10,0])
# Out:
# [1210.88 1441.29 4778.68     nan 3448.13  349.46 2330.87 1753.87  960.61
#  2911.45]

# %% [markdown]
# ## filtering Rows

# %%
display(df.iloc[[10,501,20]])
# Out:
#      serial_no        date  user_id  product_id  quantity_purchased    price  \
# 10        1010  2016-07-01     5914         975                   6   876.55
# 501       1501  2016-01-15     5763         898                   1  4918.98
# 20        1020         NaN     5861         389                  27  2831.71
#
#     user_type
# 10          n
# 501         c
# 20          n

# %%
# excluding specific row indices
display(df.drop([0,24,51], axis=0).head())
# Out:
#    serial_no        date  user_id  product_id  quantity_purchased    price  \
# 1       1001  2016-01-19     5763         898                   2  1441.29
# 2       1002         NaN     5358         896                  18  4778.68
# 3       1003  2016-08-02     5691         442                   6      NaN
# 4       1004  2016-05-02     5492         227                  17  3448.13
# 5       1005         NaN     5811         196                   1   349.46
#
#   user_type
# 1         n
# 2         n
# 3         n
# 4         n
# 5         n

# %%
# conditional filtering
display(df[df.quantity_purchased>25].head())
# Out:
#     serial_no        date  user_id  product_id  quantity_purchased    price  \
# 7        1007  2016-01-30     5491         421                  31  1753.87
# 8        1008         NaN     5294         583                  35   960.61
# 11       1011         NaN     5688         818                  37   221.30
# 12       1012  2016-01-30     5298         354                  41  1022.79
# 13       1013  2016-09-01     5165         957                  30  5454.48
#
#    user_type
# 7          n
# 8          n
# 11         n
# 12         n
# 13         n

# %%
# display values after row 100
display(df[100:].head())
# Out:
#      serial_no        date  user_id  product_id  quantity_purchased    price  \
# 100       1100  2016-10-01     5861         116                   1  4160.30
# 101       1101  2016-01-15     5763         898                  27   858.68
# 102       1102  2016-01-21     5358         896                  31  3992.89
# 103       1103  2016-01-23     5691         442                  36  5948.33
# 104       1104  2016-01-26     5492         227                  13  1844.06
#
#     user_type
# 100         c
# 101         d
# 102         b
# 103         d
# 104         c

# %% [markdown]
# ## Data Type Conversion

# %%
df['date'] = pd.to_datetime(df.date)
# compare dtypes of the original df with this one
print(df.dtypes)
# Out:
# serial_no                      int32
# date                  datetime64[ns]
# user_id                        int64
# product_id                     int64
# quantity_purchased             int32
# price                        float64
# user_type                     object
# dtype: object

# %%
df['user_class'] = df['user_type'].map(expand_user_type)
display(df.tail())
# Out:
#      serial_no       date  user_id  product_id  quantity_purchased    price  \
# 995       1995 2016-11-02     5904         582                  23  3297.96
# 996       1996 2016-01-24     5086         602                  14  2566.05
# 997       1997 2016-01-31     5637        1021                  15   973.05
# 998       1998 2016-01-13     5431         207                   2  1118.85
# 999       1999 2016-01-28     5857         586                   8  1431.09
#
#     user_type user_class
# 995         b        new
# 996         a        new
# 997         b        new
# 998         a        new
# 999         c   existing

# %% [markdown]
# ## Missing Values

# %%
# drop rows with missing values
df_dropped = df.dropna(subset=['date'])
display(df_dropped.head())
# Out:
#    serial_no       date  user_id  product_id  quantity_purchased    price  \
# 1       1001 2016-01-19     5763         898                   2  1441.29
# 3       1003 2016-08-02     5691         442                   6      NaN
# 4       1004 2016-05-02     5492         227                  17  3448.13
# 6       1006 2016-11-02     5873         295                  19  2330.87
# 7       1007 2016-01-30     5491         421                  31  1753.87
#
#   user_type user_class
# 1         n      error
# 3         n      error
# 4         n      error
# 6         n      error
# 7         n      error

# %%
# fill places with mean prices where price values are missing
df_dropped['price'].fillna(value=np.round(df.price.mean(),decimals=2),
                                inplace=True)

# %%
# fill missing values with previous row values
df_dropped['user_type'].fillna(method='ffill',inplace=True)

# %%
# fill missing values with next row values
df_dropped['user_type'].fillna(method='bfill',inplace=True)

# %% [markdown]
# ## Duplicate

# %%
# drop duplicate serial no rows
display(df_dropped[df_dropped.duplicated(subset=['serial_no'])].head())
print("Shape of df={}".format(df_dropped.shape))
# Out:
#      serial_no       date  user_id  product_id  quantity_purchased    price  \
# 95          -1 2016-01-29     5904         582                   5  1823.99
# 176         -1 2016-01-17     5156         273                  33  4100.23
# 212         -1 2016-06-02     5298         354                  35  2085.78
# 273         -1 2016-02-01     5471         350                  19   460.99
# 317         -1 2016-01-23     5729         610                  40  3355.91
#
#     user_type      user_class
# 95          d  loyal_existing
# 176         b             new
# 212         b             new
# 273         d  loyal_existing
# 317         a             new
# Shape of df=(969, 8)

# %%
df_dropped.drop_duplicates(subset=['serial_no'],inplace=True)

# %%
# updated dataframe
display(df_dropped.head())
print("Shape of df={}".format(df_dropped.shape))
# Out:
#    serial_no       date  user_id  product_id  quantity_purchased    price  \
# 1       1001 2016-01-19     5763         898                   2  1441.29
# 3       1003 2016-08-02     5691         442                   6  2281.30
# 4       1004 2016-05-02     5492         227                  17  3448.13
# 6       1006 2016-11-02     5873         295                  19  2330.87
# 7       1007 2016-01-30     5491         421                  31  1753.87
#
#   user_type user_class
# 1         n      error
# 3         n      error
# 4         n      error
# 6         n      error
# 7         n      error
# Shape of df=(941, 8)

# %%
# remove rows that have missing values for 3 or more missing values
display(df.dropna(thresh=3).head())
print("Shape of df={}".format(df.dropna(thresh=3).shape))
# Out:
#    serial_no       date  user_id  product_id  quantity_purchased    price  \
# 0       1000        NaT     -101           0                   3  1210.88
# 1       1001 2016-01-19     5763         898                   2  1441.29
# 2       1002        NaT     5358         896                  18  4778.68
# 3       1003 2016-08-02     5691         442                   6      NaN
# 4       1004 2016-05-02     5492         227                  17  3448.13
#
#   user_type user_class
# 0         n      error
# 1         n      error
# 2         n      error
# 3         n      error
# 4         n      error
# Shape of df=(1000, 8)

# %% [markdown]
# ### One hot Encoding using dummies

# %%
display(pd.get_dummies(df,columns=['user_type']).head())
# Out:
#    serial_no       date  user_id  product_id  quantity_purchased    price  \
# 0       1000        NaT     -101           0                   3  1210.88
# 1       1001 2016-01-19     5763         898                   2  1441.29
# 2       1002        NaT     5358         896                  18  4778.68
# 3       1003 2016-08-02     5691         442                   6      NaN
# 4       1004 2016-05-02     5492         227                  17  3448.13
#
#   user_class  user_type_a  user_type_b  user_type_c  user_type_d  user_type_n
# 0      error            0            0            0            0            1
# 1      error            0            0            0            0            1
# 2      error            0            0            0            0            1
# 3      error            0            0            0            0            1
# 4      error            0            0            0            0            1

# %%
type_map={'a':0,'b':1,'c':2,'d':3,np.NAN:-1}
df['encoded_user_type'] = df.user_type.map(type_map)
display((df.tail()))
# Out:
#      serial_no       date  user_id  product_id  quantity_purchased    price  \
# 995       1995 2016-11-02     5904         582                  23  3297.96
# 996       1996 2016-01-24     5086         602                  14  2566.05
# 997       1997 2016-01-31     5637        1021                  15   973.05
# 998       1998 2016-01-13     5431         207                   2  1118.85
# 999       1999 2016-01-28     5857         586                   8  1431.09
#
#     user_type user_class  encoded_user_type
# 995         b        new                1.0
# 996         a        new                0.0
# 997         b        new                1.0
# 998         a        new                0.0
# 999         c   existing                2.0

# %% [markdown]
# ### Random Sampling

# %%
display(df.sample(frac=0.2, replace=True, random_state=42).head())
# Out:
#      serial_no       date  user_id  product_id  quantity_purchased    price  \
# 102       1102 2016-01-21     5358         896                  31  3992.89
# 435       1435 2016-10-02     5073         561                  31   916.69
# 860       1860 2016-01-25     5210        1036                  31  2222.81
# 270       1270 2016-01-21     5193         837                  39  4106.23
# 106       1106 2016-09-01     5873         295                   8  1266.83
#
#     user_type      user_class  encoded_user_type
# 102         b             new                1.0
# 435         a             new                0.0
# 860         d  loyal_existing                3.0
# 270         a             new                0.0
# 106         a             new                0.0

# %%
df_normalized = df.dropna().copy()
min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(df_normalized['price'].values.reshape(-1,1))
df_normalized['price'] = np_scaled.reshape(-1,1)

# %%
display(df_normalized.head())
# Out:
#     serial_no       date  user_id  product_id  quantity_purchased     price  \
# 25       1025 2016-07-02     5947         724                  38  0.121558
# 28       1028 2016-01-24     5729         365                   8  0.430469
# 31       1031 2016-01-25     5287         423                  11  0.446637
# 32       1032 2016-01-28     5478         587                  19  0.270123
# 33       1033 2016-07-02     5026         693                  27  0.081741
#
#    user_type user_class  encoded_user_type
# 25         c   existing                2.0
# 28         c   existing                2.0
# 31         a        new                0.0
# 32         b        new                1.0
# 33         c   existing                2.0

# %% [markdown]
# ### Data Summarization
# ##### Condition based aggregation

# %%
print("Mean price of items purchased by user_type=a :: {}".format(df['price'][df['user_type']=='a'].mean()))
# Out:
# Mean price of items purchased by user_type=a :: 2320.0688796680497

# %%
print(df['purchase_week'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'purchase_week'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-eb145f754163> in <module>
#       1
# ----> 2 print(df['purchase_week'].value_counts())
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'purchase_week'

# %%
df_normalized = df.dropna().copy()
robust_scaler = preprocessing.RobustScaler()
rs_scaled = robust_scaler.fit_transform(df_normalized['quantity_purchased'].values.reshape(-1,1))
df_normalized['quantity_purchased'] = rs_scaled.reshape(-1,1)

# %%
display(df_normalized.head())
# Out:
#     serial_no       date  user_id  product_id  quantity_purchased    price  \
# 25       1025 2016-07-02     5947         724            0.809524  1179.56
# 28       1028 2016-01-24     5729         365           -0.619048  4169.34
# 31       1031 2016-01-25     5287         423           -0.476190  4325.82
# 32       1032 2016-01-28     5478         587           -0.095238  2617.44
# 33       1033 2016-07-02     5026         693            0.285714   794.20
#
#    user_type user_class  encoded_user_type
# 25         c   existing                2.0
# 28         c   existing                2.0
# 31         a        new                0.0
# 32         b        new                1.0
# 33         c   existing                2.0

# %%
print(df['purchase_week'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'purchase_week'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-4d3de1277f41> in <module>
# ----> 1 print(df['purchase_week'].value_counts())
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'purchase_week'

# %%
print(df.groupby(['user_class'])['quantity_purchased'].sum())
# Out:
# user_class
# error               614
# existing           5307
# loyal_existing     4131
# new               10935
# Name: quantity_purchased, dtype: int32

# %%
#Group by different function
display(df.groupby(['user_class'])['quantity_purchased'].agg([np.sum,
                                                                np.mean,
                                                                np.count_nonzero]))
# Out:
#                   sum       mean  count_nonzero
# user_class
# error             614  20.466667             30
# existing         5307  20.730469            256
# loyal_existing   4131  19.394366            213
# new             10935  21.826347            501

# %%
#Group by each attribute
display(df.groupby(['user_class','user_type']).agg({'price':np.mean,
                                                        'quantity_purchased':np.max}))
# Out:
#                                 price  quantity_purchased
# user_class     user_type
# error          n          2389.228621                  41
# existing       c          2233.233387                  41
# loyal_existing d          2353.936029                  41
# new            a          2320.068880                  41
#                b          2219.072227                  41

# %% [markdown]
# ### Pivot Table

# %%
display(df.pivot_table(index='date', columns='user_type', 
                         values='price',aggfunc=np.mean))
# Out:
# user_type             a            b            c            d          n
# date
# 2016-01-01  1172.006667   736.785000  2732.185000  3242.052000        NaN
# 2016-01-02  2154.998000  2438.504286  3410.580000  1607.255000        NaN
# 2016-01-13  2063.042857  1714.803333  2358.487500  2220.764000        NaN
# 2016-01-14  2035.215000  2452.012500  2144.764286  1262.297500        NaN
# 2016-01-15  2704.510000  2739.723333  2243.435000  1780.790000        NaN
# 2016-01-16  2167.166667  2445.985000   175.975000  2447.473333        NaN
# 2016-01-17  1493.020000  2711.101667  2873.464000  2563.130000        NaN
# 2016-01-18  5233.170000  2173.563333  1763.718000  2115.112000  2911.4500
# 2016-01-19  2467.864000  2032.688000  2731.185000   155.670000  2888.4150
# 2016-01-20  1366.632000  3388.130000  2764.355714   477.125000        NaN
# 2016-01-21  1839.318333  2263.523750  2004.766667   992.844000        NaN
# 2016-01-22  1422.708000  1139.766000  2598.394000  2530.953333        NaN
# 2016-01-23  2317.075556  1731.000000  2166.634000  2623.366000        NaN
# 2016-01-24  2051.653846  2050.596667  1964.932000  3355.840000        NaN
# 2016-01-25  2257.290000  1881.164000  1902.676250  2561.358000  2289.6600
# 2016-01-26  3050.123333  2556.745000  1723.683750  3315.965000        NaN
# 2016-01-27  3177.360000  1704.143333  2023.021667  2294.628000        NaN
# 2016-01-28  1489.842857  3055.626000  1924.206667  2422.147143        NaN
# 2016-01-29  2096.564000  2353.530000  1934.501667  1443.190000        NaN
# 2016-01-30   937.556667  2460.200000  3048.648333  2968.085000  1517.9475
# 2016-01-31  2714.771429  3203.646667  2436.590000  2243.971667        NaN
# 2016-02-01  2209.510000  1436.995000  1486.083333  2785.133333        NaN
# 2016-02-02  3455.076667  2843.376000  2914.920000  1711.142500        NaN
# 2016-03-01  1890.710000  2127.363333   583.800000  2485.196667        NaN
# 2016-03-02  2264.792000  1900.174286  2341.520000  4201.045000        NaN
# 2016-04-01  1308.662500  1164.797500  2113.641250  1831.557143        NaN
# 2016-04-02  1215.745714  2037.680000  2093.398000  3197.770000  1521.8900
# 2016-05-01  2568.090000  2872.090000   729.980000  1546.967500        NaN
# 2016-05-02  2801.798000  3460.865000  1373.065000  2633.701429  2156.1900
# 2016-06-01  2548.797500  2466.933000  1649.531000  2403.876667        NaN
# 2016-06-02  2185.575000  2179.861667  2676.048571  2373.865000        NaN
# 2016-07-01  2351.176000  1493.427778  3098.922857  2926.637500   876.5500
# 2016-07-02  2026.122500  2090.635714  2208.460000  1639.305714        NaN
# 2016-08-01  1951.856154  2007.502500  2773.196667    99.910000        NaN
# 2016-08-02  3830.530000  1713.683333  1952.410000   864.852500        NaN
# 2016-09-01  2797.566000  2313.932500  1806.672857  1489.350000  5454.4800
# 2016-09-02  3008.955000  1862.382500  3491.390000  2078.560000        NaN
# 2016-10-01  3020.508571  1922.090000  2392.928333  2978.870000        NaN
# 2016-10-02  2284.207500  2766.596250  2677.625000  1839.420000        NaN
# 2016-11-01  2688.082000  2255.491667  1721.908333  2688.963333        NaN
# 2016-11-02  3250.960000  2414.553333  1570.765000  2862.442857  2005.3550
# 2016-12-01  3270.024000  2560.642857  2191.252500  3443.602000        NaN

# %% [markdown]
# ## Stack Dataframe

# %%
print(df.stack())
# Out:
# 0    serial_no                            1000
#      user_id                              -101
#      product_id                              0
#      quantity_purchased                      3
#      price                             1210.88
#      user_type                               n
#      user_class                          error
# 1    serial_no                            1001
#      date                  2016-01-19 00:00:00
#      user_id                              5763
#      product_id                            898
#      quantity_purchased                      2
#      price                             1441.29
#      user_type                               n
#      user_class                          error
# 2    serial_no                            1002
#      user_id                              5358
#      product_id                            896
#      quantity_purchased                     18
#      price                             4778.68
#      user_type                               n
#      user_class                          error
# 3    serial_no                            1003
#      date                  2016-08-02 00:00:00
#      user_id                              5691
#      product_id                            442
#      quantity_purchased                      6
#      user_type                               n
#      user_class                          error
# 4    serial_no                            1004
#                                   ...
# 996  user_type                               a
#      user_class                            new
#      encoded_user_type                       0
# 997  serial_no                            1997
#      date                  2016-01-31 00:00:00
#      user_id                              5637
#      product_id                           1021
#      quantity_purchased                     15
#      price                              973.05
#      user_type                               b
#      user_class                            new
#      encoded_user_type                       1
# 998  serial_no                            1998
#      date                  2016-01-13 00:00:00
#      user_id                              5431
#      product_id                            207
#      quantity_purchased                      2
#      price                             1118.85
#      user_type                               a
#      user_class                            new
#      encoded_user_type                       0
# 999  serial_no                            1999
#      date                  2016-01-28 00:00:00
#      user_id                              5857
#      product_id                            586
#      quantity_purchased                      8
#      price                             1431.09
#      user_type                               c
#      user_class                       existing
#      encoded_user_type                       2
# Length: 8908, dtype: object
